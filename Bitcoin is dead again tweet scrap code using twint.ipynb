# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
c=twint.Config()
c.Search="Bitcoin is dead"
c.Username="sachin_rt"
c.Store_csv=True
c.Output="tweet_bitcoin.csv"

twint.run.Search(c)
# Out:
# 1542753631501709312 2022-07-01 11:45:03 +0530 <0xNiloy> People fear What they don't understand   1995 - The internet is just a Fad! 2006 - Facebook is just for Students! 2009 - Uber won't work! 2012 - Instagram is just for Kids! 2015 - LinkedIn is just for Job search! 2019 - TikTok won't last long! 2022 - Bitcoin is Dead!
# 1542752802073616384 2022-07-01 11:41:45 +0530 <w66n> Regardless of what happened to $lunc , let us accuse the idea of ​​relying on  algorithmic Dollar and massive #lunc selling  in what caused the collapse of that project in the  past! So now, Do you think new $Luna is born dead? . .  #cryptocurrecy  #Bitcoin  @terra_money  #Solana
# 1542750075268497409 2022-07-01 11:30:55 +0530 <IBCDAO> I'm dead. #Bitcoin is down bad    https://t.co/L73G2awX2w  #BearMarketApes  https://t.co/PyycVPiTvj
# ...

# %%
import pandas as pd
pd.options.display.max_columns=500

# %%
data=pd.read_csv("tweet_bitcoin.csv")

# %%
data.shape
# Out:
# (179, 36)

# %%
data.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1542752802073616384  1542752802073616384  2022-07-01 11:41:45 IST
# 1  1542750075268497409  1542750075268497409  2022-07-01 11:30:55 IST
# 2  1542745342726361088  1542745342726361088  2022-07-01 11:12:07 IST
# 3  1542734190679994368  1542734190679994368  2022-07-01 10:27:48 IST
# 4  1542733684687904773  1542683578970083329  2022-07-01 10:25:47 IST
#
#          date      time  timezone              user_id        username  \
# 0  2022-07-01  11:41:45       530            139418789            w66n
# 1  2022-07-01  11:30:55       530  1462254455961780227          ibcdao
# 2  2022-07-01  11:12:07       530  1251249987230609409    marzellmoney
# 3  2022-07-01  10:27:48       530  1272492655071555586        chahalv_
# 4  2022-07-01  10:25:47       530   928560287237619712  charafofficial
#
#                name  place                                              tweet  \
# ...
